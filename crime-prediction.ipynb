# %% [markdown]
# # Crime Prediction using Machine Learning

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt

# %%
df_crime = pd.read_csv("data/crime-final.csv")
df_crime
# Out:
#                                                      TYPE  YEAR  MONTH  DAY  \
# 0                              Break and Enter Commercial  2019      3    7
# 1                              Break and Enter Commercial  2013      4   19
# 2                              Break and Enter Commercial  2014     12   31
# 3                              Break and Enter Commercial  2017      8   24
# 4                              Break and Enter Commercial  2015      2   13
# ...                                                   ...   ...    ...  ...
# 559878  Vehicle Collision or Pedestrian Struck (with I...  2003     11   19
# 559879  Vehicle Collision or Pedestrian Struck (with I...  2010      8    4
# 559880  Vehicle Collision or Pedestrian Struck (with I...  2004      4   19
# 559881  Vehicle Collision or Pedestrian Struck (with I...  2004      6    6
# 559882  Vehicle Collision or Pedestrian Struck (with I...  2005     11   16
#
#         HOUR  MINUTE             GEO_NAME        LAT         LON     D_SCHOOL  \
# 0          2       6  Vancouver Granville  49.266678 -123.129029   779.657216
# 1          7      43     Vancouver Centre  49.282901 -123.126558  1221.974992
# 2         20       0     Vancouver Centre  49.282786 -123.126215  1203.742734
# 3          3      59     Vancouver Centre  49.282661 -123.126206  1190.086741
# 4          2      32     Vancouver Centre  49.282762 -123.126178  1200.494511
# ...      ...     ...                  ...        ...         ...          ...
# 559878    17      35      Vancouver South  49.233763 -123.123888    87.002489
# 559879    17      15     Vancouver Centre  49.233862 -123.123875    91.134276
# 559880    13       5      Vancouver South  49.232530 -123.116083   497.656899
# 559881    14      56      Vancouver South  49.232530 -123.116083   497.656899
# 559882     9      33      Vancouver South  49.232530 -123.116083   497.656899
#
#         ...  YOUTH_FEMALE  ADULT_TOTAL  ADULT_MALE  ADULT_FEMALE  \
# 0       ...        6245.0      63710.0     29620.0       34090.0
# 1       ...        5675.0      81300.0     42965.0       38330.0
# 2       ...        5675.0      81300.0     42965.0       38330.0
# 3       ...        5005.0      84545.0     44410.0       40135.0
# 4       ...        5675.0      81300.0     42965.0       38330.0
# ...     ...           ...          ...         ...           ...
# 559878  ...        8410.0      79230.0     37360.0       41855.0
# 559879  ...        7220.0     109020.0     55535.0       53465.0
# 559880  ...        8410.0      79230.0     37360.0       41855.0
# 559881  ...        8410.0      79230.0     37360.0       41855.0
# 559882  ...        8410.0      79230.0     37360.0       41855.0
#
#         SENIOR_TOTAL  SENIOR_MALE  SENIOR_FEMALE  HOUSEHOLD_INCOME  \
# 0            16375.0       7005.0         9370.0           48325.0
# 1            11260.0       5475.0         5785.0           62040.0
# 2            11260.0       5475.0         5785.0           62040.0
# 3            15520.0       7595.0         7925.0           70080.0
# 4            11260.0       5475.0         5785.0           62040.0
# ...              ...          ...            ...               ...
# 559878       19000.0       8225.0        10765.0           42430.0
# 559879       15365.0       7005.0         8340.0           82775.0
# 559880       19000.0       8225.0        10765.0           42430.0
# 559881       19000.0       8225.0        10765.0           42430.0
# 559882       19000.0       8225.0        10765.0           42430.0
#
#         EMPLOYMENT_RATE  UNEMPLOYMENT_RATE
# 0                  63.7                5.3
# 1                  69.0                6.2
# 2                  69.0                6.2
# 3                  70.4                5.2
# 4                  69.0                6.2
# ...                 ...                ...
# 559878             56.1                8.2
# 559879             70.5                6.0
# 559880             56.1                8.2
# 559881             56.1                8.2
# 559882             56.1                8.2
#
# [559883 rows x 31 columns]

# %%
df_crime.columns
# Out:
# Index(['TYPE', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GEO_NAME', 'LAT',
#        'LON', 'D_SCHOOL', 'SCHOOL_SCORE', 'POPULATION_DENSITY',
#        'POPULATION_PERCENTAGE_CHANGE', 'POP_TOTAL', 'POP_MALE', 'POP_FEMALE',
#        'CHILDREN_TOTAL', 'CHILDREN_MALE', 'CHILDREN_FEMALE', 'YOUTH_TOTAL',
#        'YOUTH_MALE', 'YOUTH_FEMALE', 'ADULT_TOTAL', 'ADULT_MALE',
#        'ADULT_FEMALE', 'SENIOR_TOTAL', 'SENIOR_MALE', 'SENIOR_FEMALE',
#        'HOUSEHOLD_INCOME', 'EMPLOYMENT_RATE', 'UNEMPLOYMENT_RATE'],
#       dtype='object')

# %% [markdown]
# ## Model 1: Crime and School
#
# Features: YEAR, MONTH, DAY, HOUR, MINUTE, LAT, LON, D_SCHOOL, SCHOOL_SCORE
#
# Label: TYPE

# %%
df1 = df_crime[['TYPE','YEAR','MONTH','DAY','HOUR','MINUTE','LAT','LON','D_SCHOOL','SCHOOL_SCORE']]
df1
# Out:
#                                                      TYPE  YEAR  MONTH  DAY  \
# 0                              Break and Enter Commercial  2019      3    7
# 1                              Break and Enter Commercial  2013      4   19
# 2                              Break and Enter Commercial  2014     12   31
# 3                              Break and Enter Commercial  2017      8   24
# 4                              Break and Enter Commercial  2015      2   13
# ...                                                   ...   ...    ...  ...
# 559878  Vehicle Collision or Pedestrian Struck (with I...  2003     11   19
# 559879  Vehicle Collision or Pedestrian Struck (with I...  2010      8    4
# 559880  Vehicle Collision or Pedestrian Struck (with I...  2004      4   19
# 559881  Vehicle Collision or Pedestrian Struck (with I...  2004      6    6
# 559882  Vehicle Collision or Pedestrian Struck (with I...  2005     11   16
#
#         HOUR  MINUTE        LAT         LON     D_SCHOOL  SCHOOL_SCORE
# 0          2       6  49.266678 -123.129029   779.657216           6.4
# 1          7      43  49.282901 -123.126558  1221.974992           6.4
# 2         20       0  49.282786 -123.126215  1203.742734           6.4
# 3          3      59  49.282661 -123.126206  1190.086741           6.4
# 4          2      32  49.282762 -123.126178  1200.494511           6.4
# ...      ...     ...        ...         ...          ...           ...
# 559878    17      35  49.233763 -123.123888    87.002489           8.7
# 559879    17      15  49.233862 -123.123875    91.134276           8.7
# 559880    13       5  49.232530 -123.116083   497.656899           8.7
# 559881    14      56  49.232530 -123.116083   497.656899           8.7
# 559882     9      33  49.232530 -123.116083   497.656899           8.7
#
# [559883 rows x 10 columns]

# %%
# Scale data and split data into train and test
scaler = StandardScaler()
y = df1['TYPE'].values
X = df1.iloc[:,1:].values
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (447906, 9) (447906,)
# Testing set:  (111977, 9) (111977,)

# %% [markdown]
# ### K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
kNN = KNeighborsClassifier(n_neighbors = 7).fit(X_train,y_train)
pred_kNN = kNN.predict(X_test)
pred_kNN[0:5]
# Out:
# array(['Break and Enter Residential/Other', 'Theft from Vehicle',
#        'Other Theft', 'Other Theft', 'Break and Enter Residential/Other'],
#       dtype=object)

# %%
print("KNN Accuracy: ", accuracy_score(y_test, pred_kNN))
# Out:
# KNN Accuracy:  0.39661716245300377

# %%
# Print confusion matrix
confusion_matrix(y_test, pred_kNN)
# Out:
# array([[ 1349,   610,  1322,   554,  3697,   105,   110,     0,    86],
#        [  601,  3831,  1393,   869,  5839,   133,   329,     0,   216],
#        [ 1239,  1990,  3010,  1629,  8037,   206,   311,     0,   180],
#        [  270,   634,   778,  8181,  2858,   124,    65,     0,   115],
#        [ 1521,  3551,  3778,  2876, 28300,   566,   744,     0,   190],
#        [  222,   523,   595,   675,  3634,   425,    65,     0,    37],
#        [  353,  1210,   862,   411,  5001,    60,   453,     0,    64],
#        [    4,     7,    15,     4,    25,     4,     1,     0,     1],
#        [  341,   961,   766,   913,  1741,    57,    86,     0,   264]])

# %%
# Find best k
Ks = 10
mean_acc = np.zeros((Ks-1))
std_acc = np.zeros((Ks-1))

for n in range(1,Ks):    
    kNN = KNeighborsClassifier(n_neighbors = n).fit(X_train,y_train)
    pred_kNN=kNN.predict(X_test)
    mean_acc[n-1] = accuracy_score(y_test, pred_kNN)
    std_acc[n-1]=np.std(pred_kNN==y_test)/np.sqrt(pred_kNN.shape[0])

mean_acc
# Out:
# array([0.32837994, 0.31921734, 0.34395456, 0.36850425, 0.38257857,
#        0.39021406, 0.39661716, 0.40392223, 0.40912866])

# %%
print( "The best accuracy was with", mean_acc.max(), "with k=", mean_acc.argmax()+1)
# Out:
# The best accuracy was with 0.40912866034989326 with k= 9

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
decisionTree = DecisionTreeClassifier()
decisionTree.fit(X_train,y_train)
pred_decisionTree = decisionTree.predict(X_test)
pred_decisionTree [0:5]
# Out:
# array(['Theft from Vehicle', 'Theft from Vehicle', 'Other Theft',
#        'Mischief', 'Mischief'], dtype=object)

# %%
print("Decision Tree's Accuracy: ", accuracy_score(y_test, pred_decisionTree))
# Out:
# Decision Tree's Accuracy:  0.40031435026835865

# %%
confusion_matrix(y_test, pred_decisionTree)
# Out:
# array([[ 1888,   662,  1502,   322,  2249,   461,   475,     5,   269],
#        [  719,  3884,  2193,   197,  3841,   663,  1152,     8,   554],
#        [ 1603,  2191,  3837,   839,  5301,   901,  1165,    10,   755],
#        [  313,   178,   896,  9992,   950,   321,   186,     3,   186],
#        [ 2547,  4109,  5992,  1013, 20785,  2578,  3712,     7,   783],
#        [  403,   654,   862,   291,  2331,  1125,   385,     2,   123],
#        [  480,  1258,  1167,   165,  3443,   403,  1298,     4,   196],
#        [    9,     7,     7,     3,     9,     2,     4,     0,    20],
#        [  341,   534,   808,   183,   835,   182,   214,    15,  2017]])

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
pred_rfc = rfc.predict(X_test)
pred_rfc[0:5]
# Out:
# array(['Break and Enter Residential/Other', 'Mischief', 'Other Theft',
#        'Other Theft', 'Other Theft'], dtype=object)

# %%
print("Random Forest Accuracy: ", accuracy_score(y_test, pred_rfc))
# Out:
# Random Forest Accuracy:  0.5193477231931557

# %%
confusion_matrix(y_test, pred_rfc)
# Out:
# array([[ 1923,   374,  1320,   213,  3472,   119,   106,     0,   149],
#        [  288,  4917,  1412,    55,  5910,   157,   290,     0,   336],
#        [  998,  1761,  4005,   649,  8339,   214,   287,     1,   443],
#        [   78,    88,   531, 10963,  1065,    63,    25,     0,   114],
#        [  935,  2683,  2653,   588, 32952,   531,   983,     0,   342],
#        [  165,   448,   541,   227,  3948,   795,    48,     1,    95],
#        [  146,   947,   557,   101,  5780,    65,   518,     0,   142],
#        [    2,     7,    15,     1,    12,     0,     0,     0,    23],
#        [  189,   685,   807,   177,  1049,    33,    38,     1,  2082]])

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             Break and Enter Commercial       0.41      0.25      0.31      7676
#                      Break and Enter Residential/Other       0.41      0.37      0.39     13365
#                                               Mischief       0.34      0.24      0.28     16697
#                                            Other Theft       0.84      0.85      0.85     12927
#                                     Theft from Vehicle       0.53      0.79      0.63     41667
#                                       Theft of Bicycle       0.40      0.13      0.19      6268
#                                       Theft of Vehicle       0.23      0.06      0.10      8256
# Vehicle Collision or Pedestrian Struck (with Fatality)       0.00      0.00      0.00        60
#   Vehicle Collision or Pedestrian Struck (with Injury)       0.56      0.41      0.47      5061
#
#                                               accuracy                           0.52    111977
#                                              macro avg       0.41      0.34      0.36    111977
#                                           weighted avg       0.49      0.52      0.48    111977

# %% [markdown]
# ## Model 2: Crime with school and census
# Features:'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GEO_NAME' (one hot encoded), 'LAT', 'LON', 'D_SCHOOL', 'SCHOOL_SCORE', 'POPULATION_DENSITY', 'POPULATION_PERCENTAGE_CHANGE', 'POP_MALE', 'CHILDREN_TOTAL', 'YOUTH_MALE', 'ADULT_TOTAL', 'ADULT_MALE', 'ADULT_FEMALE', 'HOUSEHOLD_INCOME', 'EMPLOYMENT_RATE'
#
# Label: TYPE

# %%
df2 = df_crime[['TYPE', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GEO_NAME', 'LAT',
       'LON', 'D_SCHOOL', 'SCHOOL_SCORE', 'POPULATION_DENSITY', 'POPULATION_PERCENTAGE_CHANGE', 
        'POP_MALE', 'CHILDREN_TOTAL', 'YOUTH_MALE', 
        'ADULT_TOTAL', 'ADULT_MALE', 'ADULT_FEMALE',
        'HOUSEHOLD_INCOME', 'EMPLOYMENT_RATE'
        ]]
df2
# Out:
#                                                      TYPE  YEAR  MONTH  DAY  \
# 0                              Break and Enter Commercial  2019      3    7
# 1                              Break and Enter Commercial  2013      4   19
# 2                              Break and Enter Commercial  2014     12   31
# 3                              Break and Enter Commercial  2017      8   24
# 4                              Break and Enter Commercial  2015      2   13
# ...                                                   ...   ...    ...  ...
# 559878  Vehicle Collision or Pedestrian Struck (with I...  2003     11   19
# 559879  Vehicle Collision or Pedestrian Struck (with I...  2010      8    4
# 559880  Vehicle Collision or Pedestrian Struck (with I...  2004      4   19
# 559881  Vehicle Collision or Pedestrian Struck (with I...  2004      6    6
# 559882  Vehicle Collision or Pedestrian Struck (with I...  2005     11   16
#
#         HOUR  MINUTE             GEO_NAME        LAT         LON     D_SCHOOL  \
# 0          2       6  Vancouver Granville  49.266678 -123.129029   779.657216
# 1          7      43     Vancouver Centre  49.282901 -123.126558  1221.974992
# 2         20       0     Vancouver Centre  49.282786 -123.126215  1203.742734
# 3          3      59     Vancouver Centre  49.282661 -123.126206  1190.086741
# 4          2      32     Vancouver Centre  49.282762 -123.126178  1200.494511
# ...      ...     ...                  ...        ...         ...          ...
# 559878    17      35      Vancouver South  49.233763 -123.123888    87.002489
# 559879    17      15     Vancouver Centre  49.233862 -123.123875    91.134276
# 559880    13       5      Vancouver South  49.232530 -123.116083   497.656899
# 559881    14      56      Vancouver South  49.232530 -123.116083   497.656899
# 559882     9      33      Vancouver South  49.232530 -123.116083   497.656899
#
#         ...  POPULATION_DENSITY  POPULATION_PERCENTAGE_CHANGE  POP_MALE  \
# 0       ...         4620.300000                           3.6   48295.0
# 1       ...         9206.648697                          13.6   53000.0
# 2       ...         9206.648697                          13.6   53000.0
# 3       ...        10466.500000                          13.6   59980.0
# 4       ...         9206.648697                          13.6   53000.0
# ...     ...                 ...                           ...       ...
# 559878  ...         4718.500000                           2.8   59350.0
# 559879  ...         9104.500000                          11.0   68550.0
# 559880  ...         4718.500000                           2.8   59350.0
# 559881  ...         4718.500000                           2.8   59350.0
# 559882  ...         4718.500000                           2.8   59350.0
#
#         CHILDREN_TOTAL  YOUTH_MALE  ADULT_TOTAL  ADULT_MALE  ADULT_FEMALE  \
# 0              11500.0      5630.0      63710.0     29620.0       34090.0
# 1               5795.0      5145.0      81300.0     42965.0       38330.0
# 2               5795.0      5145.0      81300.0     42965.0       38330.0
# 3               6970.0      4410.0      84545.0     44410.0       40135.0
# 4               5795.0      5145.0      81300.0     42965.0       38330.0
# ...                ...         ...          ...         ...           ...
# 559878         17795.0      8975.0      79230.0     37360.0       41855.0
# 559879          8250.0      6370.0     109020.0     55535.0       53465.0
# 559880         17795.0      8975.0      79230.0     37360.0       41855.0
# 559881         17795.0      8975.0      79230.0     37360.0       41855.0
# 559882         17795.0      8975.0      79230.0     37360.0       41855.0
#
#         HOUSEHOLD_INCOME  EMPLOYMENT_RATE
# 0                48325.0             63.7
# 1                62040.0             69.0
# 2                62040.0             69.0
# 3                70080.0             70.4
# 4                62040.0             69.0
# ...                  ...              ...
# 559878           42430.0             56.1
# 559879           82775.0             70.5
# 559880           42430.0             56.1
# 559881           42430.0             56.1
# 559882           42430.0             56.1
#
# [559883 rows x 21 columns]

# %%
# One-hot encoding districts
district_onehot = pd.get_dummies(df2[['GEO_NAME']], prefix="", prefix_sep="")
df2 = pd.concat([df2, district_onehot], axis=1)
df2.drop(['GEO_NAME'], axis=1, inplace=True)
df2
# Out:
#                                                      TYPE  YEAR  MONTH  DAY  \
# 0                              Break and Enter Commercial  2019      3    7
# 1                              Break and Enter Commercial  2013      4   19
# 2                              Break and Enter Commercial  2014     12   31
# 3                              Break and Enter Commercial  2017      8   24
# 4                              Break and Enter Commercial  2015      2   13
# ...                                                   ...   ...    ...  ...
# 559878  Vehicle Collision or Pedestrian Struck (with I...  2003     11   19
# 559879  Vehicle Collision or Pedestrian Struck (with I...  2010      8    4
# 559880  Vehicle Collision or Pedestrian Struck (with I...  2004      4   19
# 559881  Vehicle Collision or Pedestrian Struck (with I...  2004      6    6
# 559882  Vehicle Collision or Pedestrian Struck (with I...  2005     11   16
#
#         HOUR  MINUTE        LAT         LON     D_SCHOOL  SCHOOL_SCORE  ...  \
# 0          2       6  49.266678 -123.129029   779.657216           6.4  ...
# 1          7      43  49.282901 -123.126558  1221.974992           6.4  ...
# 2         20       0  49.282786 -123.126215  1203.742734           6.4  ...
# 3          3      59  49.282661 -123.126206  1190.086741           6.4  ...
# 4          2      32  49.282762 -123.126178  1200.494511           6.4  ...
# ...      ...     ...        ...         ...          ...           ...  ...
# 559878    17      35  49.233763 -123.123888    87.002489           8.7  ...
# 559879    17      15  49.233862 -123.123875    91.134276           8.7  ...
# 559880    13       5  49.232530 -123.116083   497.656899           8.7  ...
# 559881    14      56  49.232530 -123.116083   497.656899           8.7  ...
# 559882     9      33  49.232530 -123.116083   497.656899           8.7  ...
#
#         ADULT_MALE  ADULT_FEMALE  HOUSEHOLD_INCOME  EMPLOYMENT_RATE  \
# 0          29620.0       34090.0           48325.0             63.7
# 1          42965.0       38330.0           62040.0             69.0
# 2          42965.0       38330.0           62040.0             69.0
# 3          44410.0       40135.0           70080.0             70.4
# 4          42965.0       38330.0           62040.0             69.0
# ...            ...           ...               ...              ...
# 559878     37360.0       41855.0           42430.0             56.1
# 559879     55535.0       53465.0           82775.0             70.5
# 559880     37360.0       41855.0           42430.0             56.1
# 559881     37360.0       41855.0           42430.0             56.1
# 559882     37360.0       41855.0           42430.0             56.1
#
#         Vancouver Centre  Vancouver East  Vancouver Granville  \
# 0                      0               0                    1
# 1                      1               0                    0
# 2                      1               0                    0
# 3                      1               0                    0
# 4                      1               0                    0
# ...                  ...             ...                  ...
# 559878                 0               0                    0
# 559879                 1               0                    0
# 559880                 0               0                    0
# 559881                 0               0                    0
# 559882                 0               0                    0
#
#         Vancouver Kingsway  Vancouver Quadra  Vancouver South
# 0                        0                 0                0
# 1                        0                 0                0
# 2                        0                 0                0
# 3                        0                 0                0
# 4                        0                 0                0
# ...                    ...               ...              ...
# 559878                   0                 0                1
# 559879                   0                 0                0
# 559880                   0                 0                1
# 559881                   0                 0                1
# 559882                   0                 0                1
#
# [559883 rows x 26 columns]

# %%
# Scale data and split data into train and test
scaler = StandardScaler()
y = df2['TYPE'].values
X = df2.iloc[:,1:].values
X = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20)
print("Training set: ", X_train.shape, y_train.shape)
print("Testing set: ", X_test.shape, y_test.shape)
# Out:
# Training set:  (447906, 25) (447906,)
# Testing set:  (111977, 25) (111977,)

# %%
rfc = RandomForestClassifier()
rfc.fit(X_train,y_train)
pred_rfc = rfc.predict(X_test)
pred_rfc[0:5]
# Out:
# array(['Theft from Vehicle', 'Break and Enter Residential/Other',
#        'Theft from Vehicle', 'Other Theft', 'Other Theft'], dtype=object)

# %%
print("Random Forest Accuracy: ", accuracy_score(y_test, pred_rfc))
# Out:
# Random Forest Accuracy:  0.5115872009430508

# %%
print(confusion_matrix(y_test, pred_rfc))
# Out:
# [[ 1910   365  1325   267  3584   120   106     0   126]
#  [  285  4751  1438    86  6108   145   278     0   274]
#  [  883  1781  3925   736  8523   174   274     0   355]
#  [   94   116   456 10876  1203    58    30     0    92]
#  [  877  2618  2582   700 33014   479   906     0   314]
#  [  167   444   499   280  4105   714    60     0    74]
#  [  139   935   542   115  5906    67   513     0   101]
#  [    1     6    13     2    20     0     0     1    15]
#  [  168   740   865   291  1285    37    54     2  1582]]

# %%
print(classification_report(y_test, pred_rfc))
# Out:
#                                                         precision    recall  f1-score   support
#
#                             Break and Enter Commercial       0.42      0.24      0.31      7803
#                      Break and Enter Residential/Other       0.40      0.36      0.38     13365
#                                               Mischief       0.34      0.24      0.28     16651
#                                            Other Theft       0.81      0.84      0.83     12925
#                                     Theft from Vehicle       0.52      0.80      0.63     41490
#                                       Theft of Bicycle       0.40      0.11      0.18      6343
#                                       Theft of Vehicle       0.23      0.06      0.10      8318
# Vehicle Collision or Pedestrian Struck (with Fatality)       0.33      0.02      0.03        58
#   Vehicle Collision or Pedestrian Struck (with Injury)       0.54      0.31      0.40      5024
#
#                                               accuracy                           0.51    111977
#                                              macro avg       0.44      0.33      0.35    111977
#                                           weighted avg       0.48      0.51      0.47    111977
